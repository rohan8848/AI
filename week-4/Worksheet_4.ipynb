# %%
from zipfile import ZipFile

with ZipFile('/content/Copy of devnagari digit.zip', 'r') as zip_ref:
    print(zip_ref.namelist())
# Out:
# ['DevanagariHandwrittenDigitDataset/Test/digit_0/103277.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/103281.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/103309.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/103311.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/103322.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/103325.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/103340.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/103343.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/103358.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/103366.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/103369.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/103372.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/103380.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/103386.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/103396.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/103398.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/103401.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/103404.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/103414.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/103421.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/103424.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/103425.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/103427.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/103439.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/12286.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/12296.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/12305.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/12313.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/12314.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/12333.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/12346.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/12348.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/12350.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/12352.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/12358.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/12376.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/12385.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/12388.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/12391.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/12392.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/13438.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/18494.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/18506.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/18517.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/18528.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/18532.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/18534.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/18547.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/18549.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/22752.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/22760.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/22763.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/28805.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/28806.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/28818.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/28822.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/28824.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/28826.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/28831.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/28832.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/28833.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/28837.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/28838.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/28843.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/28852.png', 'DevanagariHandwrittenDigitDataset/Test/digit_0/28853.png', 'DevanagariHand ...

# %%
with ZipFile('/content/Copy of devnagari digit.zip', 'r') as zip_ref:
    zip_ref.extractall()

# %% [markdown]
# # **Task 1: Data Preparation**

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from PIL import Image # Import Pillow
# Define dataset paths
train_dir = "/content/DevanagariHandwrittenDigitDataset/Train"
test_dir = "/content/DevanagariHandwrittenDigitDataset/Test"
# Define image size
img_height, img_width = 28, 28
# Function to load images and labels using PIL
# Function to load images and labels using PIL
def load_images_from_folder(folder):
    images = []
    labels = []
    class_names = sorted(os.listdir(folder)) # Sorted class names (digit_0, digit_1, ...)
    class_map = {name: i for i, name in enumerate(class_names)} # Map class names to labels
    for class_name in class_names:
        class_path = os.path.join(folder, class_name)
        label = class_map[class_name]
        for filename in os.listdir(class_path):
            img_path = os.path.join(class_path, filename)
            # Load image using PIL
            img = Image.open(img_path).convert("L") # Convert to grayscale
            img = img.resize((img_width, img_height)) # Resize to (28,28)
            img = np.array(img) / 255.0 # Normalize pixel values to [0,1]
            images.append(img)
            labels.append(label)
    return np.array(images), np.array(labels)
# Load training and testing datasets
x_train, y_train = load_images_from_folder(train_dir)
x_test, y_test = load_images_from_folder(test_dir)
# Reshape images for Keras input
x_train = x_train.reshape(-1, img_height, img_width, 1) # Shape (num_samples, 28, 28, 1)
x_test = x_test.reshape(-1, img_height, img_width, 1)
# One-hot encode labels
y_train = to_categorical(y_train, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)
# Print dataset shape
print(f"Training set: {x_train.shape}, Labels: {y_train.shape}")
print(f"Testing set: {x_test.shape}, Labels: {y_test.shape}")
# Visualize some images
plt.figure(figsize=(10, 4))
for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.imshow(x_train[i].reshape(28, 28), cmap='gray') # Corrected cmap to 'gray'
    plt.title(f"Label: {np.argmax(y_train[i])}")
    plt.axis("off")
plt.show()
# Out:
# Training set: (17000, 28, 28, 1), Labels: (17000, 10)
# Testing set: (3000, 28, 28, 1), Labels: (3000, 10)

# %% [markdown]
# ### **Task 2: Build the FCN Model**

# %%
# Model parameters
import tensorflow as tf
from tensorflow import keras
num_classes = 10
input_shape = (28, 28, 1)
model = keras.Sequential(
  [
    keras.layers.Input(shape=input_shape),
    keras.layers.Flatten(), # Flatten the 28x28 image to a 784-dimensional vector
    keras.layers.Dense(64, activation="sigmoid"),
    keras.layers.Dense(128, activation="sigmoid"),
    keras.layers.Dense(256, activation="sigmoid"),
    keras.layers.Dense(num_classes, activation="softmax"),
  ]
)

# %% [markdown]
# ### Model Summary

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)                    │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │          50,240 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 128)                 │           8,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 256)                 │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 10)                  │           2,570 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 94,154 (367.79 KB)
#  Trainable params: 94,154 (367.79 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Task 3: Compile the Model

# %%
model.compile(
optimizer="adam", # Stochastic Gradient Descent
loss="categorical_crossentropy", # Loss function for multi-class classification
metrics=["accuracy"] # Track accuracy during training
)

# %% [markdown]
# ### **Task 4: Train the Model**

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# ModelCheckpoint to save the best model during training
checkpoint = ModelCheckpoint("best_model.h5", monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)

# EarlyStopping to stop training if validation loss doesn't improve
early_stopping = EarlyStopping(monitor='val_loss', patience=5, verbose=1)

# Train the model with callbacks
history = model.fit(
    x_train,
    y_train,
    batch_size=128,
    epochs=20,
    validation_split=0.2,
    callbacks=[checkpoint, early_stopping]
)
# Out:
# Epoch 1/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.0000e+00 - val_loss: 14.2883
# Epoch 2/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9999 - loss: 0.0011 - val_accuracy: 0.0000e+00 - val_loss: 14.3342
# Epoch 3/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 8.6892e-04 - val_accuracy: 0.0000e+00 - val_loss: 14.3931
# Epoch 4/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 7.9877e-04 - val_accuracy: 0.0000e+00 - val_loss: 14.3655
# Epoch 5/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 8.2276e-04 - val_accuracy: 0.0000e+00 - val_loss: 14.5903
# Epoch 6/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 6.8149e-04 - val_accuracy: 0.0000e+00 - val_loss: 14.5542
# Epoch 7/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 6.8132e-04 - val_accuracy: 0.0000e+00 - val_loss: 14.7156
# Epoch 8/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 1.0000 - loss: 5.5814e-04 - val_accuracy: 0.0000e+00 - val_loss: 14.7601
# Epoch 9/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 5.0928e-04 - val_accuracy: 0.0000e+00 - val_loss: 14.8193
# Epoch 10/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 1.0000 - loss: 4.5187e-04 - val_accuracy: 0.0000e+00 - val_loss: 14.9274
# Epoch 11/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 1.0000 - loss: 4.1751e-04 - val_accuracy: 0.0000e+00 - val_loss: 14.9908
# Epoch 12/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 3.8931e-04 - val_accuracy: 0.0000e+00 - val_loss: 15.0568
# Epoch 13/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 3.3946e-04 - val_accuracy: 0.0000e+00 - val_loss: 15.1277
# Epoch 14/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 1.0000 - loss: 3.3346e-04 - val_accuracy: 0.0000e+00 - val_loss: 15.0860
# Epoch 15/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 1.0000 - loss: 2.9240e-04 - val_accuracy: 0.0000e+00 - val_loss: 15.1850
# Epoch 16/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 1.0000 - loss: 2.7579e-04 - val_accuracy: 0.0000e+00 - val_loss: 15.2533
# Epoch 17/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 1.0000 - loss: 2.5482e-04 - val_accuracy: 0.0000e+00 - val_loss: 15.3599
# Epoch 18/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 1.0000 - loss: 2.3117e-04 - val_accuracy: 0.0000e+00 - val_loss: 15.3827
# Epoch 19/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 1.0000 - loss: 2.1261e-04 - val_accuracy: 0.0000e+00 - val_loss: 15.3828
# Epoch 20/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 1.9652e-04 - val_accuracy: 0.0000e+00 - val_loss: 15.4937

# %% [markdown]
# ## **Task 5: Evaluate the Model**

# %%
loss, accuracy = model.evaluate(
       x=x_test,
       y=y_test,
       batch_size=64,
       verbose=2
   )

print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# 47/47 - 0s - 3ms/step - accuracy: 0.7850 - loss: 3.1896
# Test Loss: 3.1896
# Test Accuracy: 0.7850

# %% [markdown]
# # **Task 6: Save and Load the Model**

# %%
# Save the trained model
model.save("my_trained_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## **Load The Model**

# %%
from tensorflow import keras

# Load the saved model
loaded_model = keras.models.load_model("my_trained_model.h5")

# Re-evaluate the model
loss, accuracy = loaded_model.evaluate(x_test, y_test, verbose=1)

print(f"Loaded Model - Test Loss: {loss:.4f}")
print(f"Loaded Model - Test Accuracy: {accuracy:.4f}")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9603 - loss: 0.4660
# Loaded Model - Test Loss: 3.1896
# Loaded Model - Test Accuracy: 0.7850

# %% [markdown]
# ## **Task 7: Predictions**

# %%
# Making Predictions
predictions = model.predict(x_test)

# Convert predictions from probabilities to digit labels
predicted_labels = np.argmax(predictions, axis=1)

for i in range(10):
    print(f"Image {i + 1}:")
    print(f"  Predicted label: {predicted_labels[i]}")
    print(f"  True label: {np.argmax(y_test[i])}")
    print()
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Image 1:
#   Predicted label: 0
#   True label: 0
#
# Image 2:
#   Predicted label: 0
#   True label: 0
#
# Image 3:
#   Predicted label: 0
#   True label: 0
#
# Image 4:
#   Predicted label: 0
#   True label: 0
#
# Image 5:
#   Predicted label: 0
#   True label: 0
#
# Image 6:
#   Predicted label: 0
#   True label: 0
#
# Image 7:
#   Predicted label: 0
#   True label: 0
#
# Image 8:
#   Predicted label: 0
#   True label: 0
#
# Image 9:
#   Predicted label: 0
#   True label: 0
#
# Image 10:
#   Predicted label: 0
#   True label: 0

# %%
import matplotlib.pyplot as plt

# Assuming you have trained your model and stored the training history in the 'history' variable

# Plot training & validation accuracy values
plt.figure(figsize=(12, 4))  # Adjust figure size if needed

plt.subplot(1, 2, 1)  # Create a subplot for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.subplot(1, 2, 2)  # Create a subplot for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.show()
